# %%
# + (Addition) operator
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a=10.52
b='sainath'
print(a+b) #here we have error because we cannot add string with another datatype for this we have change the float into the string.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-fab7e0f54f53> in <cell line: 3>()
#       1 a=10.52
#       2 b='sainath'
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
a=10.52
a=str(a)
b='sainath'
print(a+b)
# Out:
# 10.52sainath

# %%
# - (subratraction or difference operator)
a=10
b=20
print(a-b)
# Out:
# -10

# %%
# * -(multiplication operator or product)
a=10
b=20
print(a*b)
# Out:
# 200

# %%
# division -> /
a=100
b=30
print(a/b) # division operator make operation until we get the remainder as 0 and give quotient as a output.
# Out:
# 3.3333333333333335

# %%
#floor division -> //
a=100
b=22
print(a//b) # floor divison make operation and gives the int value only that mean eliminate the float values.
# Out:
# 4

# %%
# modulo function ->%
a=100
b=23
print(a%b) # modulo function gives the final remainder as a input
# Out:
# 8

# %%
# square
a=5
print(a*a)
# Out:
# 25

# %%
# cube
a=5
print(a*a*a)
# Out:
# 125

# %%
#pow -> **
a=10
print(a ** a)
# Out:
# 10000000000

# %%
# we also have a builtin function for power as pow
a=5
print(pow(5,3))
# Out:
# 125

# %%
a=pow(7,2,5)
print(a) # here the operation takes place as 1st it calculate 7 pow 2 and the result is divided by 5 and finds the remainder as a output.
# Out:
# 4

# %%
# =
a=10
b=a
print(b)# assain left side variable of = to the right side variable
# Out:
# 10

# %%
# ==
a=10
b=20
print(a==b) # checks the lhs and rhs equal or not and give the boolean as a output
# Out:
# False

# %%
# > greaterthan
a=10
b=20
print(a>b)
# Out:
# False

# %%
# < lessthan
a=10
b=20
print(a<b)
# Out:
# True

# %%
# >= greaterthan or equal to
a=10
b=10
print(a>=b)
# Out:
# True

# %%
# <= lessthan or equal to
a=10
b=20
print(a<=b)
# Out:
# True

# %%
# and operator
# if both the conditions are then it will give true as a output
a=10>20
b=20<30
print(a  and  b)
# Out:
# False

# %%
# or operator
# if any one of the condition is true then it will print the true as a output
a=10>20
b=20<30
print(a or b)
# Out:
# True
